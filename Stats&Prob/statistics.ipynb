# %% [markdown]
# ### Statistics
# is a branch of mathematics that involves collecting,
# analysing, interpreting, and presenting data. It provides tools and
# methods to understand and make sense of large amounts of data
# and to draw conclusions and make decisions based on the data.
#  In practice, statistics is used in a wide range of fields, such as
# business, economics, social sciences, medicine, and engineering. It is
# used to conduct research studies, analyse market trends, evaluate
# the effectiveness of treatments and interventions, and make
# forecasts and predictions.
# ### Examples:
# 1. Business - Data Analysis(Identifying customer behavior) and
#    Demand Forecasting
# 2. Medical - Identify efficacy of new medicines(Clinical trials),
#    Identifying risk factor for diseases(Epidemiology)
# 3. Government & Politics - Conducting surveys, Polling
# 4. Environmental Science - Climate research

# %% [markdown]
# ### Descriptive statistics deals with the
# collection, organization, analysis,
# interpretation, and presentation of data.
# It focuses on summarizing and describing
# the main features of a set of data, without
# making inferences or predictions about the
# larger population.
#
#
# ### Inferential statistics deals with making
# conclusions and predictions about a population
# based on a sample. It involves the use of
# probability theory to estimate the likelihood of
# certain events occurring, hypothesis testing to
# determine if a certain claim about a population is
# supported by the data, and regression analysis to
# examine the relationships between variables

# %% [markdown]
# ###  Population Vs Sample
#
# ###  Population refers to the entire group of individuals or objects that we are
# interested in studying. It is the complete set of observations that we want to make
# inferences about. For example, the population might be all the students in a
# particular school or all the cars in a particular city.
# ###  A sample, on the other hand, is a subset of the population. It is a smaller group of
# individuals or objects that we select from the population to study. Samples are
# used to estimate characteristics of the population, such as the mean or the
# proportion with a certain attribute. For example, we might randomly select 100
# students.
#  Examples
#  1. All cricket fans vs fans who were present in the stadium
#  2. All students vs who visit college for lectures
#
# Things to be careful about which creating samples
# 1. Sample Size
# 2. Random
# 3.  Representative
#
# ### Parameter Vs Statistics :-
#  A parameter is a characteristic of a population, while a statistic is a characteristic
# of a sample. Parameters are generally unknown and are estimated using statistics.
# The goal of statistical inference is to use the information obtained from the sample
# to make inferences about the population parameters

# %% [markdown]
# ###  Inferential statistics is a branch of statistics that deals with making inferences or predictions
# about a larger population based on a sample of data. It involves using statistical techniques to
# test hypotheses and draw conclusions from data. Some of the topics that come under
# inferential statistics are:
#  1. Hypothesis testing: This involves testing a hypothesis about a population parameter based
# on a sample of data. For example, testing whether the mean height of a population is
# different from a given value.
# 2. Confidence intervals: This involves estimating the range of values that a population
# parameter could take based on a sample of data. For example, estimating the population
# mean height within a given confidence level.
# 3. Analysis of variance (ANOVA): This involves comparing means across multiple groups to
# determine if there are any significant differences. For example, comparing the mean
# height of individuals from different regions.
# 4. Regression analysis: This involves modelling the relationship between a dependent
# variable and one or more independent variables. For example, predicting the sales of a
# product based on advertising expenditure.
#  5. Chi-square tests: This involves testing the independence or association between two
# categorical variables. For example, testing whether gender and occupation are
# independent variables.
# 6.  Sampling techniques: This involves ensuring that the sample of data is representative of
# the population. For example, using random sampling to select individuals from a
# population.
# 7. Bayesian statistics: This is an alternative approach to statistical inference that involves
# updating beliefs about the probability of an event based on new evidence. For example,
# updating the probability of a disease given a positive test result.
#
#
#
#  Why ML is closely associated with statistics?

# %% [markdown]
# Because machine learning learns patterns from uncertain data, and statistics is the science of reasoning, estimating, and generalizing under uncertainty.

# %% [markdown]
# ### Types of of data
# 1. Categorical data  eg:- gender
#   a. Nominal data :-
#       male/female
#   b. Ordinal Data :-
#       bad , good , avg ( order data of smthg )
# 2. Numerical / Quantitative data eg:- Age, height
#   a.Dicrete data :-
#        age/rank  ( whole digit )
#   b.Continous data:-
#        weights of the entries

# %% [markdown]
# ## Measure of Central Tendency
#
#  A measure of central tendency is a statistical measure that represents a typical or
# central value for a dataset. It provides a summary of the data by identifying a
# single value that is most representative of the dataset as a whole.

# %% [markdown]
#  ### The mean is the sum of all values in the dataset divided by the number of values ,
# ### Median , Mode , Trimmed mean , Weighted mean , Measure of Dispersion ( spread of the data )
# ### Range , Variance = Summation of (x-u)^2 / n , Standard Deviation = (variance)^0.5  9 It gives the same unit as it is data have ,
# ###  Coefficient of variation , standard deviation / mean * 100 give the mean amount of the variablity in the data set realtive to the mean , dimension less as well

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 📊 Descriptive Statistics - Graphs
#
# ## 🔹 Univariate Analysis
# - **Categorical:** Frequency table, Relative & Cumulative Frequency.
# - **Numerical:** Histogram → shows data shape (symmetric, skewed, etc.).
#
# ## 🔹 Bivariate Analysis
# - **Cat vs Cat:** Contingency Table (Crosstab).
# - **Num vs Num:** Scatter Plot (relation between variables).
# - **Cat vs Num:** Compare numerical values across categories (Boxplot/Bar).

# %%
import pandas as pd
import numpy as np

# %%
## Contengency table 
gender=['Male','Female']
passed=[40,45]
failed=[10,5]
import matplotlib.pyplot as plt
x=np.arange(len(gender))
plt.bar(gender,passed)    #gender wise how many got passed or not
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(x-0.2,passed)
plt.bar(x+0.2,failed) ## grouped bar
# Out:
# <BarContainer object of 2 artists>

# %%
### stacked plotting 
plt.bar(gender,passed)
plt.bar(gender,failed,bottom=passed)
# Out:
# <BarContainer object of 2 artists>

# %%
data = np.array([
    [40, 10],
    [45, 5]
])
plt.imshow(data)
# Heatmaps are used when:
#    both axes are discrete
#    values represent strength, frequency, or association
# Typical uses:
#    contingency tables
#    correlation matrices
#    confusion matrices
#    feature importance grids

# %% [markdown]
# ### Why contour plots are preferred for continuous space
# ##### When data varies smoothly over a continuous domain (x–y plane, physical space, time–space)
# #####     Contour plots show level curves (equal-value lines)
# #####     They preserve gradients and topology
# #####     You can see how values change continuously, not in blocks
# ##### This matches the mathematics of continuous functions.
# ##### Why heatmaps are weaker here
# ##### Heatmaps:
# #####   discretize space into cells
# #####   imply artificial boundaries
# #####   hide smooth transitions unless resolution is very high
# ##### So for temperature fields, pressure maps, elevation surfaces → contours are more truthful.

# %%
# What a contour plot actually is
# A contour plot is a way to represent a 3-variable relationship on a 2D plane.
# You have:
# x → first variable
# y → second variable
# 𝑧 = 𝑓(𝑥,𝑦)
# z=f(x,y) → value depending on both
# A contour plot shows where 𝑧 stays constant.
# So each contour line means:
# “At all these (x, y) points, the value of z is the same.”
# Exactly like height lines on a topographic map.

# %%
x = np.linspace(-2, 6, 100)
y = np.linspace(-2, 4, 100)
X, Y = np.meshgrid(x,y)
Z =X**2 + Y**2 -4*X + 2*Y +5
plt.contour(X, Y, Z)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Contour plot of z=x²+y²-4x+2y+5 ")
plt.show()

# %% [markdown]
# ### Covarience  and Correlation

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.DataFrame()

# %%
from re import X
x = pd.Series([12,25,68,42,113])
y = pd.Series([11,29,58,121,100])

# %%
df['x'] = x
df['y'] = y

# %%
df
# Out:
#      x    y
# 0   12   11
# 1   25   29
# 2   68   58
# 3   42  121
# 4  113  100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

# Plot scatterplots on each axes
ax1.scatter(df['x'],df['y'])
ax2.scatter(df['x']*2, df['y']*2)

ax1.set_title("Covariance - " + str(np.cov(df['x'],df['y'])[0,1]))
ax2.set_title("Covariance - " + str(np.cov(df['x']*2,df['y']*2)[0,1]))
# Out:
# Text(0.5, 1.0, 'Covariance - 4595.0')

# %%
print(np.cov(df['x'],df['y'])[0,1])
print(np.cov(df['x']*2,df['y']*2)[0,1])
# Out:
# 1148.75
# 4595.0

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 3))

# Plot scatterplots on each axes
ax[0].scatter(df['x'], df['x'])
ax[1].scatter(df['x'], df['y'])
ax[2].scatter(df['x']*2, df['y']*2)

ax[0].set_title("Covariance - " + str(np.cov(df['x'],df['x'])[0,1]))
ax[1].set_title("Covariance - " + str(np.cov(df['x'],df['y'])[0,1]))
ax[2].set_title("Covariance - " + str(np.cov(df['x']*2,df['y']*2)[0,1]))
# Out:
# Text(0.5, 1.0, 'Covariance - 4595.0')

# %% [markdown]
# ### Correlation

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

# Plot scatterplots on each axes
ax1.scatter(df['x'], df['x'])
ax2.scatter(df['x'], df['y'])

ax1.set_title("Correlation - " + str(df['x'].corr(df['x'])))
ax2.set_title("Correlation - " + str((df['x']).corr(df['y'])))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.6185423626205997')

# %% [markdown]
# # Probability distributions

# %%
import pandas as pd 
import random

L = []
for i in range(10000):
  a = random.randint(1,6)
  b = random.randint(1,6)

  L.append(a)

# %%
len(L)
L[:5]
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()
s.plot(kind="bar")
# Out:
# <Axes: >

# %%
import numpy as np
np.cumsum(s)   ## it gives the cdf of the pmf function
# Out:
# 1    0.1599
# 2    0.3245
# 3    0.4882
# 4    0.6520
# 5    0.8207
# 6    1.0000
# Name: count, dtype: float64

# %%
s.plot(kind='bar')
# Out:
# <Axes: >

# %%
np.cumsum(s).plot(kind='bar') ## Commulative distribution function (CDF)
# Out:
# <Axes: >

# %% [markdown]
# # Probablity Density functions

# %% [markdown]
# ### The probability density function (PDF) of a continuous random variable describes how the probability is distributed over different possible values of that variable.
# #### P(a≤X≤b)=∫​f(x)dx with limit range ot a to b , we will integrating this area which will give us the probablity then so area is the probality
# #### ===>   −∞∫∞​f(x)dx=1
#
# ### Some famous Pdf :- Poisson distrbution , Normal distribution , Log distribution

# %% [markdown]
# ### So how we calculate these things so density estimation comes into picture which uses the two ways that is parametric and non parametric techniques , paremetric asssumes data is following certan specific distribution and non parametric estimated from the data only .
# #### Involves technique such as kernel density estimation , histogram estimation , gaussian mixture model (GMMS)

# %% [markdown]
# #### Now we will implement he parametric density function on the data such as

# %%
### we will try to match data with any other distributions 

import matplotlib.pyplot as plt 
import numpy as np 
from numpy.random import normal
sample=normal(loc=50,scale=5,size=1000)
sample
sample.mean()
## plot histogram to undertand the distribution 
plt.hist(sample, bins=10)

###   calculate sample mean and sample std dev
sample_mean=sample.mean()
sample_std=sample.std()  



### fitting the distribution with the above parameters 
from scipy.stats import norm 
dist=norm(sample_mean,sample_std)

values=np.linspace(sample.min(),sample.max(),100)
 
probabilities=[dist.pdf(value) for value in values ]
plt.hist(sample,bins=10,density =True)
plt.plot(values,probabilities,color='red')
plt.ylim(0,0.09)
# Out:
# (0.0, 0.09)

# %% [markdown]
# ### in Seaborn graph

# %%
import seaborn as sns
sns.displot(sample)
sns.lineplot(x=values, y=probabilities)
plt.xlabel("Values")
plt.ylabel("Probability Density")
plt.title("Probability Density Function")
plt.show()

# %% [markdown]
# #### Non-parametric density estimation makes no assumption about the distribution form. Instead, it estimates the probability density function (PDF) directly from the data. // does not required the use of predefined distrbutions functions , as opposed to parametric methods such as the Gaussian distrition
# #### we use each data point to derive it ans does through the KDE plot only , it does not require the assumption of a specific destrbution , which allows for more flexible and accurate elimation in situations where the underlying distribution is unknown or complex, however non parametric density estimation can be computationalyy intensive and may require more data to achive accurate estimates compared to parametic methods

# %% [markdown]
# #### Instead of assuming a fixed distribution (like Gaussian), KDE builds the density by placing a kernel (a smooth bump, usually Gaussian) on each data point, then sums them up.

# %%
sample1=normal(loc=20,scale=5,size=300)
sample2=normal(loc=40,scale=5,size=700)
sample=np.hstack((sample1,sample2))
sample
plt.hist(sample,bins=50)
# Out:
# (array([ 2.,  0.,  0.,  3.,  2.,  3.,  3.,  6., 13., 13., 16., 17., 15.,
#         24., 25., 29., 23., 23., 20., 15., 13., 11.,  8., 13.,  8., 14.,
#         11., 12., 34., 34., 35., 49., 61., 51., 52., 50., 54., 46., 34.,
#         31., 31., 24., 21., 14., 14., 13.,  5.,  2.,  2.,  1.]),
#  array([ 4.56914629,  5.57925737,  6.58936846,  7.59947955,  8.60959064,
#          9.61970173, 10.62981282, 11.63992391, 12.650035  , 13.66014609,
#         14.67025717, 15.68036826, 16.69047935, 17.70059044, 18.71070153,
#         19.72081262, 20.73092371, 21.7410348 , 22.75114589, 23.76125698,
#         24.77136806, 25.78147915, 26.79159024, 27.80170133, 28.81181242,
#         29.82192351, 30.8320346 , 31.84214569, 32.85225678, 33.86236786,
#         34.87247895, 35.88259004, 36.89270113, 37.90281222, 38.91292331,
#         39.9230344 , 40.93314549, 41.94325658, 42.95336766, 43.96347875,
#         44.97358984, 45.98370093, 46.99381202, 48.00392311, 49.0140342 ,
# ...

# %%
from sklearn.neighbors import KernelDensity

model = KernelDensity(bandwidth=3, kernel='tophat')

# convert data to a 2D array
sample = sample.reshape((len(sample), 1))

model.fit(sample)
# Out:
# KernelDensity(bandwidth=3, kernel='tophat')

# %%
values = np.linspace(sample.min(),sample.max(),100)
values = values.reshape((len(values), 1))

# %%
probabilities = model.score_samples(values)
probabilities = np.exp(probabilities)

# %% [markdown]
# #### Score_samples(values) returns the log-density estimate of the input samples values. This is because the score_samples() method of the KernelDensity class returns the logarithm of the probability density estimate rather than the actual probability density estimate.

# %%
plt.hist(sample, bins=50, density=True)
plt.plot(values[:], probabilities)
plt.show()

# %%
sns.kdeplot(sample.reshape(1000),bw_adjust=0.01
            )
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure()
sns.kdeplot(data=df,x='sepal_length',hue='species')
plt.figure()
sns.kdeplot(data=df,x='sepal_width',hue='species')
plt.figure()
sns.kdeplot(data=df,x='petal_length',hue='species')
plt.figure()
sns.kdeplot(data=df,x='petal_width',hue='species')
plt.Figure()
sns.ecdfplot(data=df,x="petal_width",hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
# so , by analysing it we are sure that we will take the petal_width , petal lenght as the feature for our model

# %%
import pandas as pd
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# code here
sns.kdeplot(data=titanic,x='Age',hue='Survived')

sns.jointplot(data=df, x="petal_length", y="sepal_length", kind="kde",fill=True,cbar=True)
plt.figure()
sns.kdeplot(titanic['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
titanic['Age'].mean()
x = (titanic['Age'] - titanic['Age'].mean())/titanic['Age'].std()

sns.kdeplot(x)
# Out:
# np.float64(80.0)

# %%
x.mean()
x.std()
titanic['Age'].skew()
titanic['Age'].skew()
# Out:
# np.float64(80.0)

# %%
titanic['Age'].mean() + 3*titanic['Age'].std()
titanic['Age'].mean() - 3*titanic['Age'].std()
titanic['Age'].max()
titanic[titanic['Age'] > 73]

# The 3-sigma method defines statistical boundaries:
# Upper boundary = μ + 3σ
# Lower boundary = μ − 3σ
# Any data point outside these boundaries is labeled an outlier.
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 630  male  80.0      0      0   27042  30.000   A23        S
# 851  male  74.0      0      0  347060   7.775   NaN        S

# %% [markdown]
# ### Q-Q plot

# %% [markdown]
# General diagnostic tool used to access whether two probablity distribution are identical upto loacation scale transformation
# sorterdd by indexed data by probablity ..

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')

# %%
sns.kdeplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
temp=sorted(df['sepal_length'].tolist())

# %%
y_quant=[]
for i in range(1,101):
    y_quant.append(np.percentile(temp,i))

# %%
sample=np.random.normal(loc=0,scale=1,size=1000)

# %%
x_quant=[]
for i in range(1,101):  
    x_quant.append(np.percentile(sample,i))
plt.scatter(x_quant,y_quant)
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.title("Q-Q Plot")
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
## using statsmodel for drawing the qq plot 
import statsmodels.api as sm
import matplotlib.pyplot as plt
fig=sm.qqplot(df['sepal_length'],line='45',fit=True)
plt.title("Q-Q Plot using statsmodel")
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
