# %% [markdown]
# | Function Name                  | Category                  | Purpose/Key Features                                                                             |
# | ------------------------------ | ------------------------- | ------------------------------------------------------------------------------------------------ |
# | make_blobs                     | Clustering                | Gaussian blobs; params: n_samples, n_features, centers, cluster_std, random_state geeksforgeeks​ |
# | make_circles                   | Classification/Clustering | Concentric circles; noise, factor (inner/outer radius ratio) geeksforgeeks​                      |
# | make_moons                     | Classification/Clustering | Interleaving half-circles; noise geeksforgeeks​                                                  |
# | make_classification            | Classification            | n-classes, n_informative/redundant features, n_clusters_per_class, flip_y geeksforgeeks​         |
# | make_gaussian_quantiles        | Classification            | Gaussian quantiles; n_samples, n_features, n_classes geeksforgeeks​                              |
# | make_hastie_10_2               | Classification            | 10D binary (Hastie); n_samples                                                                   |
# | make_regression                | Regression                | Linear features; n_samples, n_features, n_informative, effective_rank, noise geeksforgeeks​      |
# | make_friedman1                 | Regression                | Polynomial benchmark                                                                             |
# | make_friedman2                 | Regression                | Sine + interactions                                                                              |
# | make_friedman3                 | Regression                | Non-linear interactions                                                                          |
# | make_sparse_uncorrelated       | Regression                | Sparse uncorrelated design                                                                       |
# | make_low_rank_matrix           | Decomposition             | Low-rank + noise; n_samples, n_features, rank                                                    |
# | make_sparse_coded_signal       | Decomposition             | Sparse coding; n_samples, n_components, n_features                                               |
# | make_sparse_uncorrelated       | Biclustering              | Sparse uncorrelated patterns                                                                     |
# | make_checkerboard              | Biclustering              | Checkerboard patterns; shape, n_clusters, noise                                                  |
# | make_multilabel_classification | Multilabel                | Multi-label; n_samples, n_features, n_classes, n_labels geeksforgeeks​                           |
# | make_s_curve                   | Manifold                  | S-shaped 3D manifold                                                                             |
# | make_swiss_roll                | Manifold                  | Swiss roll manifold                                                                              |
# | make_imbalance_classification  | Imbalanced                | Imbalanced classes (v0.25+); ratio control scikit-learn​                                         |
# | make_moons                     | Repeated                  | (Also clustering, as above) geeksforgeeks​                                                       |
